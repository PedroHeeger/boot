# %% [markdown]
# * **Plataforma**: [DIO (Digital Inovation One)](/dio/)
# * **Bootcamp**: [Geração Tech Unimed-BH - Ciência de Dados: Básico; 126 Hrs](/dio/dados_unimed_1/)
# * **Módulo_Bootcamp**: [2) Python para Cientistas de Dados (21)](/dio/dados_unimed_1/02-modulo_python/)
# # 2.7) Desafio de projeto: Análise de dados com Python e Pandas (9)
# ## 2.7.1.3) Python básico

# %%
# Exibindo uma informação
print("Olá Mundo")
# Out:
# Olá Mundo

# %%
# Exibindo uma informação
print("Estou aprendendo Python")
# Out:
# Estou aprendendo Python

# %%
# Exibindo uma informação
"Estou aprendendo Python"
# Out:
# 'Estou aprendendo Python'

# %%
# Relizando uma operação aritmética de adição
1 + 1
# Out:
# 2

# %%
# Relizando uma operação aritmética de subtração
10 - 2
# Out:
# 8

# %%
# Esse é um comentário em Python

# %%
# Relizando uma operação aritmética de multiplicação
2 * 2
# Out:
# 4

# %%
# Relizando uma operação aritmética de divisão
10 / 2
# Out:
# 5.0

# %%
# Criando variáveis
a = 4
b = 6

# %%
# Relizando uma operação aritmética de adição com variáveis
a + b
# Out:
# 10

# %%
# Criando uma variável do tipo string
frase = "Python para análise de dados"
frase

# %%
# Fatiando a string
frase[0]
# Out:
# 'P'

# %%
# Fatiando a string
frase[0:10]
# Out:
# 'Python par'

# %%
# Fatiando a string:
frase[10:]
# Out:
# 'a análise de dados'

# %%
# Fatiando a string:
frase[:17]
# Out:
# 'Python para análi'

# %%
# Contando o número de ocorrências
frase.count("dados")
# Out:
# 1

# %%
# Convertendo para letra minúscula
frase.lower()
# Out:
# 'python para análise de dados'

# %%
# Convertendo para letra maiúscula
frase.upper()
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
# Substituindo informações
frase.replace("Python", "Frases")
# Out:
# 'Frases para análise de dados'

# %%
# Armazenando na varíavel o resultado de uma função
frase = frase.upper()
frase
